# %% [markdown]
# <a href="https://colab.research.google.com/github/endangrusiana123/SLO/blob/main/assignment6_endang_rusiana_201012320036.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 6: Tugas Python 2

# %% [markdown]
# 1.Download dataset data0.csv dan tempatkan pada direktori di googledrive yang akan dibaca oleh google colab

# %% [markdown]
# 2.Baca kedua dataset tersebut pada google colab pada variable yang berbeda

# %%
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/Colab Notebooks/SLO/Assignment_6/data0-SZL.csv"
data = pd.read_csv(path)
data.head()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#    953  915  989  957  942  945  964  967  951  958  ...  999.2  1008  999.3  \
# 0  951  927  984  961  943  948  965  974  952  960  ...   1002  1002   1011
# 1  949  934  981  961  943  945  966  971  954  962  ...   1006   999   1016
# 2  948  936  981  960  944  943  964  973  955  961  ...   1009   999   1012
# 3  950  935  983  960  948  944  960  970  953  960  ...   1009   999   1008
# 4  950  938  987  961  954  946  963  965  951  958  ...   1007   999   1010
#
#    1024  931  831  962.5  919  1211  952.1
# 0  1030  935  830    965  914  1204    950
# 1  1033  937  832    965  913  1175    947
# 2  1033  937  827    967  913  1134    947
# 3  1032  934  825    966  916  1084    949
# 4  1032  931  822    965  917  1039    949
#
# [5 rows x 160 columns]

# %% [markdown]
# 3.Dari data0.csv, lakukan perhitungan setiap kolomnya dan simpan perhitungan setiap kolomnya di parameter dataset baru pada kolom yang sama:<br>
# -Rata-rata<br>
# -Standar deviasi<br>
# -Skewness<br>
# -Median<br>
# -Energi<br>
# -Min<br>
# -Max

# %%
parameters = pd.DataFrame(index=['Average', 'Standard deviation', 'Skewness', 'Median', 'Energy', 'Min', 'Max'])

parameter_dfs = []

for column in data.columns:
    avg = data[column].mean()
    std_dev = data[column].std()
    skewness = data[column].skew()
    median = data[column].median()
    energy = np.sum(data[column] ** 2) / len(data[column])
    min_val = data[column].min()
    max_val = data[column].max()

    parameter_df = pd.DataFrame({
        column: [avg, std_dev, skewness, median, energy, min_val, max_val]
    }, index=['Average', 'Standard deviation', 'Skewness', 'Median', 'Energy', 'Min', 'Max'])

   parameter_dfs.append(parameter_df)

parameters = pd.concat(parameter_dfs, axis=1)

parameters.head(10)
# Out:
#                               953            915            989  \
# Average                968.532370     960.045568     967.593220
# Standard deviation      38.087937      35.910211      39.111912
# Skewness                 4.540302       4.660723       4.216797
# Median                 964.000000     956.000000     962.000000
# Energy              939505.239789  922976.677966  937765.956655
# Min                    906.000000     901.000000     901.000000
# Max                   1260.000000    1235.000000    1248.000000
#
#                               957            942            945  \
# Average                962.974437     970.038622     952.537371
# Standard deviation      39.208241      38.269399      37.387380
# Skewness                 4.389730       4.596763       4.456552
# Median                 958.000000     964.000000     948.000000
# Energy              928856.626007  942439.067797  908724.871909
# Min                    904.000000     908.000000     892.000000
# ...

# %% [markdown]
# 4.Plot sinyal diatas dari no. 2 dengan multiplot 2x3, sinyal yang diplot dapat dipilih dari 6 kolom secara bebas

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

axes = axes.flatten()

for i in range(len(axes)):
    random_column = np.random.choice(data.columns)

    axes[i].plot(data.index, data[random_column])
    axes[i].set_title(random_column)
    axes[i].set_xlabel('Index')
    axes[i].set_ylabel('Value')

plt.tight_layout()

plt.show()

# %% [markdown]
# 5.Plot scatterplot dari hasil no. 3 untuk rata-rata, buat warna dan tanda yang berbeda untuk setiap 10 kolom, kolom 1-10 warna merah *, kolom 11-20 warna biru o, kolom 21-30 warna hijau v, dst (bebas). Dimana x adalah nilai rata-rata dan y adalah nilai standar deviasi.

# %%
num_columns = parameters.shape[1]

averages = parameters.iloc[0]
std_devs = parameters.iloc[1]

num_groups = num_columns // 10

colors = plt.cm.viridis(np.linspace(0, 1, num_groups))
markers = ['o', 's', 'D', '^', 'v', 'p', '*'] * (num_groups // len(markers) + 1)

plt.figure(figsize=(10, 6))
for i in range(num_groups):
    start_col = i * 10
    end_col = (i + 1) * 10
    group_averages = averages[start_col:end_col]
    group_std_devs = std_devs[start_col:end_col]
    plt.scatter(group_averages, group_std_devs, c=[colors[i]], marker=markers[i], label=f'Columns {start_col}-{end_col}', alpha=0.5)

plt.xlabel('Average')
plt.ylabel('Standard deviation')
plt.title('Scatterplot of Average vs Standard deviation')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))

plt.grid(True)
plt.show()

# %% [markdown]
# 6.Lakukan hal yang sama spt no. 5 untuk skewness dan median

# %%
num_columns = parameters.shape[1]

_skewness = parameters.iloc[2]
_median = parameters.iloc[3]

num_groups = num_columns // 10

colors = plt.cm.viridis(np.linspace(0, 1, num_groups))
markers = ['o', 's', 'D', '^', 'v', 'p', '*'] * (num_groups // len(markers) + 1)

plt.figure(figsize=(10, 6))
for i in range(num_groups):
    start_col = i * 10
    end_col = (i + 1) * 10
    group_skewness = _skewness[start_col:end_col]
    group_median = _median[start_col:end_col]
    plt.scatter(group_skewness, group_median, c=[colors[i]], marker=markers[i], label=f'Columns {start_col}-{end_col}', alpha=0.5)

plt.xlabel('Skewness')
plt.ylabel('Median')
plt.title('Scatterplot of Skewness vs Median')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))

plt.grid(True)
plt.show()
